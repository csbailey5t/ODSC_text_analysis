# %% [markdown]
# # Exploratory Text Analysis in Python using spaCy and textacy
#
# Workshop for Open Data Science Conference East 2021 <br />
# [Workshop materials](https://github.com/csbailey5t/ODSC_text_analysis)
#
# Scott Bailey <br/>
# Digital Research and Scholarship Librarian <br/>
# Copyright and Digital Scholarship Center <br/>
# NC State University Libraries
#
# ## Outline
# 1. Intro and overview of NLP libraries
# 2. Document-level analysis <br/>
#     a. Tokenization <br/>
#     b. Cleaning text data <br />
#     c. Part-of-speech tagging <br/>
#     d. Named entity recognition <br/>
#     e. Similarity vectors <br/>
#     f. Rule-based matching <br />
# 3. Scaling up to corpus-level analysis
# 4. Further resources for spaCy
#
# ## What do we mean by "exploratory text analysis?"
# - How clean are the data?
# - What methods do the data support?
# - Project scoping
# - Research question refinement
# - Iterative research
#
# ## A quick(!) overview of NLP-related libraries in Python
# - [nltk](https://www.nltk.org/)
# - [gensim](https://radimrehurek.com/gensim/)
# - [scikit-learn](https://scikit-learn.org/stable/)
# - [stanza/corenlp](https://stanfordnlp.github.io/stanza/)
# - [spaCy](https://spacy.io/)
# - [huggingface transformers - pytorch and tensorflow](https://github.com/huggingface/transformers)
#
# ### Why spaCy and textacy?
#
# SpaCy is an opinionated, performant NLP library that does a lot of the work for you while revealing where you might need to do more custom refinement or model building. Textacy builds smoothly on spaCy to add corpus analysis and common information retrieval methods.
#
# ## Questions during the workshop
#
# During the workshop, please do ask questions by way of the chat. I'll be keeping an eye on that, and will answer questions as we go if I can. I'll also give some time during and after the workshop when folks can unmute and ask questions.
#
# ## Jupyter Notebooks, Google Colab, and Binder

# %%
# Run this cell if working in Google Colab or Binder
# If working locally, install dependencies per requirements.txt
# !pip install textacy
# !python -m spacy download en_core_web_md

# %%
from collections import Counter
import glob
import spacy
from spacy import displacy
import textacy

# %%
import en_core_web_md

# %%
nlp = en_core_web_md.load()

# %%
# from https://en.wikipedia.org/wiki/Data_science
sample_text = """Data science is an inter-disciplinary field that uses scientific methods, processes, algorithms and systems to extract knowledge and insights from structured and unstructured data, and apply knowledge and actionable insights from data across a broad range of application domains. Data science is related to data mining, machine learning and big data.

Data science is a "concept to unify statistics, data analysis, informatics, and their related methods" in order to "understand and analyze actual phenomena" with data. It uses techniques and theories drawn from many fields within the context of mathematics, statistics, computer science, information science, and domain knowledge. Turing award winner Jim Gray imagined data science as a "fourth paradigm" of science (empirical, theoretical, computational and now data-driven) and asserted that "everything about science is changing because of the impact of information technology" and the data deluge."""

# %%
doc = nlp(sample_text)

# %% [markdown]
# ## Tokenization

# %%
for word in doc[:20]:
    print(word)

# %%
for noun_chunk in doc.noun_chunks:
    print(noun_chunk)

# %%
for sent in doc.sents:
    print(sent)

# %% [markdown]
# ## Cleaning text data

# %%
# One of the common things we do in text analysis is to remove punctuation
no_punct = [token for token in doc if token.is_punct == False]
for token in no_punct[50:100]:
  print(token.text, token.is_punct)

# %%
# This has worked, but left in new line characters and spaces
no_punct_or_space = [token for token in doc if token.is_punct == False and token.is_space == False]
for token in no_punct_or_space[50:100]:
  print(token.text)

# %%
# Let's say we also want to remove numbers, and lowercase everything
lower_alpha = [token.lower_ for token in no_punct_or_space if token.is_alpha == True]
lower_alpha[:30]

# %% [markdown]
# One other common bit of preprocessing is to remove stopwords, that is, the common words in a language that don't convey the information that we are looking for in our analysis. For example, if we looked for the most common words in a text, we would want to remove stopwords so that we don't only get words such as 'a,' 'the,' and 'and.'

# %%
clean = [token.lower_ for token in no_punct_or_space if token.is_alpha == True and token.is_stop == False]
clean[:30]

# %% [markdown]
# For this piece, we've used spaCy's built in stopword list, which is used to create the property `is_stop` for each token. There's a good chance you would want to create custom stopwords lists though, especially if you're working with historical text or really domain-specific text.

# %%
# We'll just pick a couple of words we know are in the example
custom_stopwords = ["data", "algorithms"]

custom_clean = [token.lower_ for token in doc if token.lower_ not in custom_stopwords]
custom_clean

# %% [markdown]
# At this point, we have a list of lower-cased tokens that doesn't contain punctuation, white-space, numbers, or stopwords. Depending on our analysis, we may or may not want to do this much cleaning. But, it is good to understand how much we can do just with spaCy.

# %% [markdown]
# ### Since we can break apart the document and filter it now, it's a good time to start counting things

# %%
print("Number of tokens in document: ", len(doc))
print("Number of tokens in cleaned document: ", len(clean))
print("Number of unique tokens in cleaned document: ", len(set(clean)))

# %%
# number of sentences
len(list(doc.sents))

# %%
# Count all lower-cased tokens
full_counter = Counter([token.lower_ for token in doc])
full_counter.most_common(20)

# %%
# Count cleaned tokens
cleaned_counter = Counter(clean)
cleaned_counter.most_common(20)

# %% [markdown]
# ### Activity
#
# In the cell below, write code to find the five most common noun chunks in the original doc.

# %%
# Write code here

# %% [markdown]
# ## Part-of-speech tagging

# %%
# Coarse grained UPOS: https://universaldependencies.org/docs/u/pos/
for token in doc[:20]:
    print(token.text, token.pos_)

# %%
# Fine-grained POS, Penn Treebank: https://www.ling.upenn.edu/courses/Fall_2003/ling001/penn_treebank_pos.html
for token in doc[:20]:
    print(token.text, token.tag_)

# %%
# Not sure what those tags are? Try spaCy's explain function
spacy.explain("DT")

# %%
# Collect tokens by part of speech
verbs = [token for token in doc if token.pos_ == "VERB"]
verbs

# %%
# Collect plural nouns
nouns_pl = [token for token in doc if token.tag_ == "NNS" or token.tag_ == "NNPS"]
nouns_pl

# %% [markdown]
# ### Dependency tree visualization

# %%
single_sentence = list(doc.sents)[0]
single_sentence

# %%
# spaCy determines the dependency tree for it's doc. Like POS, we can see the dependency tags of each token. 
for token in single_sentence:
    print(token.text, token.dep_)

# %%
spacy.explain("dobj")

# %%
displacy.render(single_sentence, style="dep", jupyter=True)

# %% [markdown]
# ## Named entity recognition
#
# [List of entity types in this spaCy model](https://spacy.io/models/en#en_core_web_md)

# %%
for ent in doc.ents:
    print(ent.text, ent.label_)

# %% [markdown]
# ### Activity
#
# Add or modify a sentence in the original `sample_text` so that spaCy will detect a GPE. Then, in the cell below, write code to return a list of all entities that are either PERSON or GPE.
#
# **hint**: make sure to reprocess the `sample_text` with the `nlp` model.

# %%
# Write code here

# %% [markdown]
# ### Visualizing named entities

# %%
single_sentence = list(doc.sents)[-1]
displacy.render(single_sentence, style="ent", jupyter=True)

# %% [markdown]
# ## Word, sentence, and document vectors
#
# SpaCy's medium (`md`) and large (`lg`) models include GloVe word vectors trained on the [Common Crawl](https://commoncrawl.org/).
#
# You could train your own vectors with `gensim` and `word2vec`, use a large language model, or many other libraries and algorithms. But, if you're text is fairly recent and especially from the web, the common crawl vectors might be enough, especially for exploratory work.
#
# `Token`s have vectors. `Doc`s and `Span`s have vectors that are the average of their token vectors.

# %%
# token vectors
for token in doc[:5]:
    print(token.vector)

# %%
# doc vector
doc.vector

# %%
# sentence/span vector
list(doc.sents)[0].vector

# %% [markdown]
# This is fine, but for exploratory work, we might just be interested in some similarity measures between tokens, sentences, or documents. SpaCy uses the common cosine similarity measure.

# %%
for token1 in doc[:10]:
    for token2 in doc[:10]:
        print(token1.text, token2.text, token1.similarity(token2))

# %% [markdown]
# **Question**: Looking at the results, can you explain the scale of the similarity score?

# %%
for sent1 in doc.sents:
    for sent2 in doc.sents:
        print(sent1.text, "\n", sent2.text, "\n", sent1.similarity(sent2))
        print("----------------------------------------------")

# %% [markdown]
# ## Rule based matcher
#
# Rule-based matching is an incredibly powerful complement to the statistic models of spaCy. It's also a bit complex though, and it's worth looking at the docs [here](https://spacy.io/usage/rule-based-matching).

# %%
for sent in doc.sents:
    print(sent)

# %%
from spacy.matcher import Matcher

# %%
matcher = Matcher(nlp.vocab)

# %% [markdown]
# [Available token attributes for the `Matcher` pattern](https://spacy.io/usage/rule-based-matching#adding-patterns-attributes)

# %%
# We'll define a pattern as a list of dictionaries, where each dictionary describes a token
pattern = [{'LOWER': 'data'},
           {'POS': 'NOUN'}]
# The Matcher expects a list of patterns
matcher.add("data+noun", [pattern])

# %%
matches = matcher(doc)
for match_id, start, end in matches:
    string_id = nlp.vocab.strings[match_id]
    span = doc[start:end]
    print(match_id, string_id, start, end, span.text)

# %% [markdown]
# One of the easiest ways to build up these `Matcher` patterns is to use Explosion's online [Rule-based Matcher Explorer](https://explosion.ai/demos/matcher).

# %% [markdown]
# ## Working with multiple documents (a corpus)
#
# For a small corpus, you can build a list or dictionary of processed spaCy docs. Once you have that list or dictionary, approach it in terms of using the type of code we've written above, but applied over the larger data structure.
#
# For larger corpora, though, you might need to think about streaming data or distributed processing.
#
# We're going to turn to textacy to work with a corpus of documents shortly, but it is useful to think about how you can use standard data structures in combination with spaCy as needed, and when it is enough for your task.

# %%
# Run this if in Colab
# Don't run this if in Binder
# !wget https://github.com/csbailey5t/ODSC_text_analysis/blob/master/archive.zip

# %%
# Run this if in Colab
# normally we would just use `unzip`, but Colab seems to be having issues with zip files and utilities, so 7-zip it is. 
# !7z x archive.zip

# %%
# Run this if in Binder
# !unzip archive.zip

# %%
# Gather the paths for all .txt files in our data directory
fns = glob.glob("sotu/*.txt")
len(fns)
# Out:
# 228

# %%
texts = []
for fn in fns:
    with open(fn, 'r') as f:
        texts.append(f.read())

# %%
# %time corpus = [nlp(text) for text in texts[:5]]

# %%
for doc in corpus[:2]:
    for ent in doc.ents:
        print(ent.text, ent.label_)

# %%
# Collect all geo-political entities from whole corpus
gpes = [(ent.text, ent.label_) for ent in doc.ents for doc in corpus if ent.label_ == "GPE"]
len(gpes)

# %%
gpes[:20]

# %%
# get the set of unique GPEs
set(gpes)

# %% [markdown]
# ### Activity
#
# Choose a method from the single document analysis portion of the workshop, and apply it to this small corpus. For example, you could find the most common words, create a cleaned corpus, or aggregate parts of speech.

# %%
# Write code here

# %% [markdown]
# spaCy also provides a `pipe` method on the language model that will process texts in a stream. This can be useful for larger collections of texts, especially when combined with disabling parts of the pipeline you aren't using.
#
# https://spacy.io/api/language#pipe

# %%
# %time docs = [nlp(text) for text in texts]

# %%
# %time docs = list(nlp.pipe(texts, batch_size=10, n_process=2))

# %% [markdown]
# Let's take a look at how to build a corpus with textacy now.
#
# Textacy corpora can be built directly from a list of texts, or could be buit from texts plus metadata, allowing you to filter the corpus on metadata. For now, we'll stick with just the texts.
#
# The full docs for textacy are [here](https://textacy.readthedocs.io/en/stable/), with details on the `Corpus` class [here](https://textacy.readthedocs.io/en/stable/api_reference/lang_doc_corpus.html#module-textacy.corpus). The `Corpus` class does provide convenience functions for saving and loading processed corpora.

# %%
# For time constraints, we'll only use the first 50 texts
corpus = textacy.Corpus(nlp, data=texts[:50])

# %%
corpus

# %%
print("number of documents: ", corpus.n_docs)
print("number of sentences: ", corpus.n_sents)
print("number of tokens: ", corpus.n_tokens)
# Out:
# number of documents:  50
# number of sentences:  15185
# number of tokens:  539271

# %%
# We'll pass as_strings so that the results we look at will give us strings rather than unique ids.
counts = corpus.word_counts(as_strings=True)

# %% [markdown]
# Notice that, by default, the word_counts function is doing a certain amount of cleaning for you: https://chartbeat-labs.github.io/textacy/api_reference/lang_doc_corpus.html#textacy.corpus.Corpus.word_counts

# %%
sorted(counts.items(), key=lambda x: x[1], reverse=True)[:20]
# Out:
# [('-PRON-', 22617),
#  ('States', 1514),
#  ('Government', 1313),
#  ('Congress', 1248),
#  ('year', 1219),
#  ('country', 1157),
#  ('United', 1144),
#  ('law', 1053),
#  ('great', 1039),
#  ('public', 968),
#  ('people', 955),
#  ('time', 866),
#  ('power', 811),
#  ('government', 798),
#  ('present', 782),
#  ('nation', 745),
#  ('interest', 730),
#  ('$', 714),
#  ('man', 693),
#  ('good', 638)]

# %% [markdown]
# For an explanation of -PRON-, see https://spacy.io/api/annotation#lemmatization. Basically it's spaCy's way of lemmatizing pronouns.

# %%
word_doc_counts = corpus.word_doc_counts(weighting="freq", smooth_idf=True, filter_stops=True, as_strings=True)

# %%
sorted(word_doc_counts.items(), key=lambda x:x[1], reverse=True)[:30]
# Out:
# [('Congress', 1.0),
#  ('-PRON-', 1.0),
#  ('nation', 1.0),
#  ('country', 1.0),
#  ('state', 1.0),
#  ('time', 1.0),
#  ('power', 1.0),
#  ('great', 1.0),
#  ('law', 1.0),
#  ('provide', 1.0),
#  ('Government', 1.0),
#  ('States', 1.0),
#  ('public', 1.0),
#  ('peace', 0.98),
#  ('policy', 0.98),
#  ('present', 0.98),
#  ('force', 0.98),
#  ('continue', 0.98),
#  ('right', 0.98),
#  ('use', 0.98),
#  ('man', 0.98),
#  ('United', 0.98),
#  ('government', 0.96),
#  ('people', 0.96),
#  ('day', 0.96),
#  ('year', 0.96),
#  ('interest', 0.96),
#  ('resource', 0.96),
#  ('effort', 0.96),
#  ('national', 0.96)]

# %% [markdown]
# We should note that these are not tf-idf values, which are term frequencies for individual docs weighted by the inverse document frequency. This is a measure of the number of docs the words appear in weighted by inverse document frequency. We're still getting a sense of which words across the corpus and in the context of the corpus seem to have the most importance, if document frequency is a proxy for importance.
#
# Textacy provides access to different algorithms that can be run on docs, such as TextRank for keyword extraction. We'll start by working on a single doc, and then look at how we might scale up to thinking about the corpus.

# %%
import textacy.ke

# %%
key_terms_textrank = textacy.ke.textrank(corpus[4])
key_terms_textrank
# Out:
# [('great force', 0.00580978182335001),
#  ('american force', 0.005377411476666639),
#  ('great contest', 0.00462661685116663),
#  ('public safety', 0.004293233802075154),
#  ('great expense', 0.004223206948674106),
#  ('great effort', 0.004127390918915549),
#  ('american arm', 0.00409940879220057),
#  ('naval force', 0.0039660352678062),
#  ('american vessel', 0.003923120658678822),
#  ('remote war', 0.0038246450106410356)]

# %% [markdown]
# For comparison, we'll take a look at another algorithm, Yake.

# %%
key_terms_yake = textacy.ke.yake(corpus[4])
key_terms_yake
# Out:
# [('american', 0.1407673789106284),
#  ('enemy', 0.16905116455611136),
#  ('war', 0.21299958777157296),
#  ('Lake', 0.22567308111444673),
#  ('Great Britain', 0.22578578528285786),
#  ('great', 0.23090677065475476),
#  ('force', 0.24616100588665138),
#  ('Captain', 0.2533484294881614),
#  ('country', 0.2592254612132675),
#  ('States', 0.27558966823053144)]

# %% [markdown]
# Let's think about aggregating keywords over part of the corpus.

# %%
key_terms_yake_corpus = [textacy.ke.yake(doc) for doc in corpus[:20]]

# %%
key_terms_yake_corpus[:2]
# Out:
# [[('Federal', 0.08419911487618757),
#   ('America', 0.08665076194977252),
#   ('Federal Government', 0.08785053639590079),
#   ('Congress', 0.11427955467685523),
#   ('program', 0.12750369660620955),
#   ('Americans', 0.13441277383892614),
#   ('state', 0.14607138179506698),
#   ('government', 0.1530721899298864),
#   ('year', 0.1534629560613433),
#   ('Union', 0.17571181410241804)],
#  [('Congress', 0.05489682095536695),
#   ('country', 0.13982690533143013),
#   ('United States', 0.1441138800324803),
#   ('law', 0.147595671288873),
#   ('Government', 0.15319227148609038),
#   ('great', 0.15409324018682413),
#   ('Philippine Islands', 0.1580781520730748),
#   ('man', 0.16299023537864987),
#   ('good', 0.16316241155270622),
#   ('Nation', 0.16322988152208626)]]

# %%
from itertools import chain

# %%
flat_terms_tuples = list(chain(*key_terms_yake_corpus))
flat_terms_tuples[:10]
# Out:
# [('Federal', 0.08419911487618757),
#  ('America', 0.08665076194977252),
#  ('Federal Government', 0.08785053639590079),
#  ('Congress', 0.11427955467685523),
#  ('program', 0.12750369660620955),
#  ('Americans', 0.13441277383892614),
#  ('state', 0.14607138179506698),
#  ('government', 0.1530721899298864),
#  ('year', 0.1534629560613433),
#  ('Union', 0.17571181410241804)]

# %%
# we now have a flat list of tuples, but let's shift to a flat list of just the keys in order to 
# count the most common keys
flat_terms = [k for k,v in flat_terms_tuples]
flat_terms[:20]
# Out:
# ['Federal',
#  'America',
#  'Federal Government',
#  'Congress',
#  'program',
#  'Americans',
#  'state',
#  'government',
#  'year',
#  'Union',
#  'Congress',
#  'country',
#  'United States',
#  'law',
#  'Government',
#  'great',
#  'Philippine Islands',
#  'man',
#  'good',
#  'Nation']

# %%
keyword_counter = Counter(flat_terms)
keyword_counter.most_common(20)
# Out:
# [('Congress', 18),
#  ('United States', 13),
#  ('Government', 9),
#  ('America', 7),
#  ('year', 7),
#  ('american', 5),
#  ('Federal Government', 4),
#  ('Americans', 4),
#  ('great', 4),
#  ('President', 4),
#  ('Treasury', 4),
#  ('state', 3),
#  ('government', 3),
#  ('Union', 3),
#  ('man', 3),
#  ('Nation', 3),
#  ('Department', 3),
#  ('Great Britain', 3),
#  ('States', 3),
#  ('General Government', 3)]

# %% [markdown]
# ## Keyword in Context
#
# One thing that researchers often find helpful in working with text is simply seeing keywords in context. Maybe you already know terms of interest in your data, but if not, the keyword extract above might help surface interesting words.

# %%
kwic_gens = [textacy.text_utils.KWIC(doc.text, "Nation") for doc in corpus[:20]]

# %%
for kwic_gen in kwic_gens:
  for entry in kwic_gen:
    print(entry)
# Out:
#  began this tradition in 1790 after reminding the
#  Nation  that the destiny of self-government and the "pres
# Roosevelt
# spoke of a day of infamy and summoned a  nation  to arms. Douglas MacArthur
# made an unforgettable
#  oldest hopes of our
# Republic--prosperity for our  nation , peace for the world, and the blessings
# of indivi
# ess that we have made in
# our relations with other  nation s, on the foundation we've carefully laid
# for our
# es to our two highest budget priorities--a strong  nation al defense
# to keep America free and at peace and a
# minority
# business assistance. And research at the  Nation al Institute of Health will
# be increased by over $
# . As
# one Democratic Governor put it recently: The  Nation al Government should be
# worrying about "arms contr
# ities to
# apply to the Federal Government for desig nation  as urban enterprise zones.
# A broad range of speci
# r spirit is still alive and well
# in America.
#
# Our  nation 's long journey towards civil rights for all our c
# ver the past year, reestablishing respect for our  nation  around the
# globe and some of the challenges and g
# ers of the major industrial powers and
# developing  nation s. Now, some of those I met with were a little sur
# arliament has called for March 21st to be an inter nation al
# day of support for Afghanistan. Well, I urge al
# y activities, as
# I announced in my address to the  Nation  last November 18th. We have
# proposed to the Sovie
# p of their military forces. The protection of our
#  nation al security has required that we undertake a subst
#  peaceful world requires a sound
# strategy and the  nation al resolve to back it up. When radical forces
# thre
# strength and resolve in their dealings with other  nation s.
# That's why we've moved to reconstruct our natio
# ations.
# That's why we've moved to reconstruct our  nation al defenses. We intend to
# keep the peace. We will
# ericans who
# overcame insuperable odds to set this  nation  on course 200 years ago. But
# our glory didn't end
# se,
# and teach the needy; millions who've made our  nation  and our nation's
# destiny so very special--unsung
# he needy; millions who've made our nation and our  nation 's
# destiny so very special--unsung heroes who may
# epresentatives. The address was broadcast live on  nation wide radio
# and television.
# wave will
# recede; but the tide will advance. This  Nation  is seated on a continent
# flanked by two great oce
# rs themselves; of men winnowed out from
# among the  nation s of the Old World by the energy, boldness, and lo
# adventure found in their own eager hearts. Such a  Nation , so placed,
# will surely wrest success from fortun
# oe or
# for weal, our place must be great among the  nation s. We may either fall
# greatly or succeed greatly;
# in no wise
# inconsistent with power to act in combi nation  for aims which can not so
# well be achieved by the
# f these powers. Corporations, and especially combi nation s of
# corporations, should be managed under public
# by State action. It must therefore be achieved by
#  nation al action. Our aim is not to do away with corporat
#  corporation.  In curbing and regulating the
# combi nation s of capital which are, or may become, injurious t
# our country has won in the leadership of the inter nation al
# industrial world, not to strike down wealth wit
# f commercial freedom and entailing restraint upon
#  nation al commerce fall within the regulative power of th
# cated.
#
# I believe that monopolies, unjust discrimi nation s, which prevent or
# cripple competition, fraudulen
# f the Congress to "regulate
# commerce with foreign  nation s and among the several States" through
# regulation
# ry reapplication of the principle to the
# shifting  nation al needs. We must take scrupulous care that the
# re
# e
# Congress after a deliberate and scientific exami nation  of the various
# schedules as they are affected by
#  the right. This is an era of federation and combi nation .
# Exactly as business men find they must often wor
# sible, even more wicked,
# even more destructive to  nation al welfare, than sectional, race, or
# religious ani
# at we keep true to the principles upon which this  Nation  was founded,
# and judge each man not as a part of
#  poor. So far as the
# constitutional powers of the  Nation al Government touch these matters of
# general and v
#  these matters of
# general and vital moment to the  Nation , they should be exercised in
# conformity with the
# des of this country toward leadership in the
# inter nation al business world justify an urgent demand for the
# hus in a
# sense Cuba has become a part of our inter nation al political system.
# This makes it necessary that
# Moreover, it is unworthy of a mighty and generous  nation ,
# itself the greatest and most successful republic
# republic of the north, should make all our
# sister  nation s of the American Continent feel that whenever the
# civilized
# powers are largely mere matters of inter nation al police duty, essential
# for the welfare of the w
# u of war to settle difficulties
# between civilized  nation s, although as yet the world has not progressed
# su
# itration in every case. The formation of the inter nation al tribunal
# which sits at The Hague is an event of
# , in which not only the United States but
# foreign  nation s may take advantage of the machinery already in
# e
# uisites of successful development. No independent  nation  in
# America need have the slightest fear of aggres
# increasing
# interdependence and complexity of inter nation al political and economic
# relations render it incu
# owed by law. It is very
# small for the size of the  Nation , and most certainly should be kept at
# the highest
# em and
# for securing the highest efficiency in the  Nation al Guard, which has
# already passed the House, shou
# t is of great importance that the relation of the  Nation al Guard to
# the militia and volunteer forces of th
#  for danger, is both foolish
# and wicked in such a  nation  as ours; and past experience has shown that
# such
# cent years than the inauguration of the system of  nation ally-aided
# irrigation for the arid regions of the
# ng
# therein has been made. Now that this policy of  nation al irrigation has
# been adopted, the need of thorou
# icious protection be permanently
# preserved on our  nation al reserves for the people as a whole, should be
# s
#  It is, for instance, a serious count against our
#  nation al good sense to permit the present practice of bu
# o whatever extent
# they may be reclaimed under the  nation al irrigation law, the remaining
# public lands shou
#  up of homes therein. Much of our prosperity as a
#  nation  has been due to the operation of the homestead la
# islation for
# Alaska. It is not to our credit as a  nation  that Alaska, which has been
# ours for thirty-five
#  making the Museum under its
# charge worthy of the  Nation , and for preserving at the National Capital
# not o
# e worthy of the Nation, and for preserving at the  Nation al Capital
# not only records of the vanishing races
# ia is the only part of our territory in which the
#  Nation al Government exercises local or municipal functio
# itself, might be made a model for
# the rest of the  Nation . We should pass, for instance, a wise
# employer's-
# Jefferson. The White
# House is the property of the  Nation , and so far as is compatible with
# living therein
# which keep alive our sense of continuity with the
#  Nation 's past.
#
# The reports of the several Executive Dep
# e ever been.
#
# It is of equal consequence that the  nation s whom Europe has usually
# supplied with innumerabl
# auses. What interests us just now is not the
# expla nation  but the fact, and our duty and opportunity in the
# e of the ores
# and forests and water powers of our  nation al domain in the rich States of
# the West, when we
#
# water power of our navigable streams outside the  nation al domain also, even
# in the eastern States, where
# ock, with
# proper safeguards, the resources of the  nation al domain, the other to
# encourage the use of the n
# has done so
# little, but also to the people of the  Nation  as a whole; and we as clearly
# owe the other fulfi
#  marks a most hopeful and decided advance in inter nation al
# civilization. We should show our earnest good f
#  more
# economically conceived and carried out. The  Nation  is not niggardly; it is
# very generous. It will ch
# to mention goes deeper into the
# principles of our  nation al life and policy. It is the subject of national
#
# ur national life and policy. It is the subject of  nation al
# defense.
#
# It can not be discussed without first
#  that we are not ready upon
# brief notice to put a  nation  in the field, a nation of men trained to arms?
# Of
# upon
# brief notice to put a nation in the field, a  nation  of men trained to arms?
# Of course we are not read
# ry is threatened. Dread of the power of any other
#  nation  we are incapable of. We are not jealous of rivalr
# et live. We are, indeed, a true
# friend to all the  nation s of the world, because we threaten none, covet th
# pportunity such as has seldom been
# vouchsafed any  nation , the opportunity to counsel and obtain peace in t
# that has
# cooled and interrupted the friendship of  nation s. This is the time above
# all others when we shoul
# an do or will do.
# We must depend in every time of  nation al peril, in the future as in the
# past, not upon a
# f true American ideas. It is right,
# too, that the  Nation al Guard of the States should be developed and
# str
#  constant policy to make these
# provisions for our  nation al peace and safety.
#
# More than this carries with
# s been misinformed. We have not been negligent of  nation al
# defense. We are not unmindful of the great resp
# rs to come, as we strive to show in our life as
# a  nation  what liberty and the inspirations of an emancipat
#  that ought to
# be brought to the attention of the  Nation al Legislature at its first
# regular session.
#
# THE
# tion declares to be illegal "every contract,
# combi nation  in the form of trust or otherwise, or conspiracy,
# commerce among the several States or with foreign  nation s," and
# in the second, declares guilty of a misdem
# or commerce of the several
# States or with foreign  nation s."
#
# In two early cases, where the statute was inv
# atute was directed against all contracts and combi nation s in restraint of
# trade whether reasonable at comm
# y
# untrue. By its judgment every contract and combi nation  in restraint of
# interstate trade made with the pu
# d by the court at common law to
# contracts or combi nation s or conspiracies in restraint of trade whose
# purp
#  assumed power to
# say that such contracts or combi nation s or conspiracies might be lawful if
# the parties t
#  of the law been laid upon the great illegal combi nation s that
# have exercised such an absolute dominion ov
# ase the Supreme and Circuit Courts found the
# combi nation  to be a monopoly of the interstate business of re
#  in effect commanded the dissolution of
# this combi nation , directed the transfer and pro rata distribution
# y and abroad, and that this had been done by combi nation s
# made with a purpose and effect to stifle competi
# ing company. The plan adopted to destroy
# the combi nation  and restore competition involved the redivision o
# ng the conspirators through whom the illegal combi nation  acquired
# and exercised its unlawful dominion. Und
# ed perpetually from in any way effecting any combi nation  between any
# of the companies in violation of the
# ital in business enterprises in which such a
# combi nation  can secure reduced cost of production, sale, and
# ich it has been necessary to tear apart this combi nation
# and force it into new forms with the attendant bu
# e
# companies are enjoined from cooperation or combi nation ; they have different
# managers, directors, purchas
#  or
# there will be activity by one company and stag nation  by another. Only a
# short time will inevitably lea
#  decisions has led to decrees dissolving the
# combi nation  of manufacturers of electric lamps, a southern wh
# cuit court compelling dissolution, and other
# combi nation s of a similar history are now negotiating with th
# l units, and to make impossible those
# useful combi nation s of capital and the reduction of the cost of prod
# ere is nothing
# in the statute which condemns combi nation s of capital or mere bigness of
# plant organized to
# t of the organization
# and maintenance of the combi nation  or the aggregation of immense size are
# the stifli
# on between the units thus combined, but
# this elimi nation  is in contravention of the statute only when the
#
# n contravention of the statute only when the
# combi nation  is made for purpose of ending this particular com
# ation. The suggestion is, that we may have a combi nation  of
# two corporations, which may run on for years,
# biners to be innocent then turns out to
# be a combi nation  in violation of the statute. The answer to this
# h
# d is attributed by the
# court to the original combi nation .
#
# NEW REMEDIES SUGGESTED.
#
# Much is said of the re
# hing can not be done by which these
# business combi nation s may be offered a means, without great financial
#
# rust statute.
#
# "Generally, in the industrial combi nation s called 'trusts,' the principal
# business is the s
# ment in
# granting a Federal charter to such a combi nation  to make and sell in
# interstate and foreign commer
# eral authority), thus avoiding the creation under
#  nation al auspices of the holding company with subordinat
# he prohibition of the anti-trust act against combi nation s in restraint
# of trade is to be effectively enfor
# be effectively enforced, it is essential that the  Nation al
# Government shall provide for the creation of na
# onal
# Government shall provide for the creation of  nation al corporations to carry
# on a legitimate business
# de and commerce
# among the States and with foreign  nation s. Every argument which was then
# advanced for such
#  was then
# advanced for such a law, and every expla nation  which was at that time
# offered to possible object
#  for the building up and regulation of legitimate
#  nation al and foreign commerce.
#
# GOVERNMENT ADMINISTRATIV
# ation permitting and aiding the
# formation of combi nation s of capital into Federal corporations. They shoul
# eep
# within the lines of the law. Other large combi nation s that fail to take
# advantage of the Federal incor
# rtunity. It is the result of the
# confident determi nation  of such a people to maintain their future growth
# mission.
#
# Do we desire to make such ruthless combi nation s and monopolies lawful? When
# all energies are dir
# extension of the policy of the settlement of
# inter nation al disputes by arbitration rather than by war, and
# positeur, the matter
# had been referred for determi nation . His Majesty made an award of nearly
# $1,000,000 t
# Panama, upon its beginning life as an
# independent  nation . Although the disputants had submitted this quest
# ity.
# A boundary commission, according to the inter nation al agreement, has now
# been appointed, and it is ex
# ving the technical neutrality obligations of inter nation al law.
#
# On the 6th of March last, in the absence
# e sovereignty of a friendly state, are due to our  nation als
# abroad.
#
# Charged as I am with the responsibili
# e to be the only guaranties for
# the safety of our  nation als and their property. If it should eventuate tha
#  might be made upon the lives and property of our
#  nation als, but the ultimate result would be order and ad
#  As a result of to-day's fighting across the
# inter nation al line, but within gunshot range of the heart of
# ented, and of thus inflaming
# Mexican popular indig nation  against many thousand Americans now in Mexico
# and
# ico and of sincere friendship for the neighboring  nation ,
# without regard for party allegiance, has been ge
# epublics to enter
# upon an era of genuine economic  nation al development. The Government of
# Nicaragua which
# deeper submergence in bankruptcy,
# revolution, and  nation al jeopardy. PANAMA.
#
# Our relations with the Repub
# ed by the joint contributions of all the American  nation s, has
# during the past year enlarged its practical
#  past year enlarged its practical work as an inter nation al
# organization, and continues to prove its useful
# ith China by the conclusion
# of two important inter nation al loans, one for the construction of the
# Hukuang
# Provinces of Hunan and Hupeh, reserving for their  nation als the privilege
# of engineering the construction
# hed whereby American, British,
# French, and German  nation als should participate upon equal terms in this
# im
#  preference with those of the other three lending
#  nation s, and as the contract provides for branches and e
#  Empire and promote
# the rapid development of inter nation al trade.
#
# NEUTRAL FINANCIAL ADVISER.
#
# When these
# solute equality in all respects among the lending  nation s
# might be scrupulously observed, the American Gov
# bserved, the American Government proposed the
# nomi nation  of a neutral adviser, which was agreed to by Chin
# understanding which has been fostered by the inter nation al projects
# referred to above and the general symp
# Far East. While safeguarding the interests of our
#  nation als, this Government is using its best efforts in
# of Admiral Count Togo to the United States as the  Nation 's
# guest afforded a welcome opportunity to demonst
# apacity to represent the United States
# at the coro nation  ceremony of the new King.
#
# EUROPE AND THE NEAR EA
# ly in its commercial standing
# with certain of the  nation s of the Near East. Turkey, especially, is
# beginni
# o closer and greater
# commercial interchange.
#
# CORO NATION  OF KING GEORGE V.
#
# The 22d of June of the present
# he 22d of June of the present year marked the coro nation  of His Britannic
# Majesty King George V. In honor
# ds of friendship happily
# existing between the two  nation s.
#
# SETTLEMENT OF LONG-STANDING DIFFERENCES WITH G
#  to
# His Majesty the German Emperor and the German  nation  in recognition of the
# gift of the statue of Frede
# ooting.
#
# RECOGNITION OF PORTUGUESE REPUBLIC.
#
# The  Nation al Constituent Assembly, regularly elected by the
#  in that archipelago are still in progress.
#
# INTER NATION AL CONVENTIONS AND CONFERENCES.
#
# INTERNATIONAL PRI
#
# INTERNATIONAL CONVENTIONS AND CONFERENCES.
#
# INTER NATION AL PRIZE COURT.
#
# The supplementary protocol to The
# Hague convention for the establishment
# of an inter nation al prize court, mentioned in my last annual messag
# ppeal to the proposed court from the
# decisions of  nation al courts, has received the signature of the gover
#  London on
# February 26, 1909 of the rules of inter nation al law to be recognized within
# the meaning of arti
# Hague convention for the establishment of
# an Inter nation al Prize Court.
#
# FUR-SEAL TREATY.
#
# The fur-seal co
# ion
# of the feasibility of securing a general inter nation al game law for the
# protection of other mammals of
# preservation of which is of
# importance to all the  nation s of the world.
#
# LEGISLATION NECESSARY.
#
# The atten
# TRIAL PROPERTY UNION.
#
# The conference of the Inter nation al Union for the Protection of Industrial
# Property
# t signed at Madrid on April 14,
# 1891 for the inter nation al registration of trade-marks, and the additional
# s
# will be promptly submitted to the Senate.
#
# INTER NATION AL OPIUM COMMISSION.
#
# In a special message transmi
# in which I announced that the
# results of the Inter nation al Opium Commission held at Shanghai in February,
#
# nment to
# secure the cooperation of the interested  nation s, the United States
# proposed an international opi
# ested nations, the United States
# proposed an inter nation al opium conference with full powers for the purpo
# or the purpose
# of clothing with the force of inter nation al law the resolutions adopted by
# the above-mentio
#  under review the municipal laws of the
# different  nation s for the mitigation of their opium and other alli
# onference which will certainly deal with the inter nation al aspects of
# these evils, it seems to me most ess
#  by any other of the
# signatory governments.
#
# INTER NATION AL ARRANGEMENT TO SUPPRESS OBSCENE PUBLICATIONS.
#
#
# UBLICATIONS.
#
# One of the notable advances in inter nation al morality accomplished in
# recent years was an ar
#  instances now appears to amount to undue
# discrimi nation  in the sense of section 2 Of the tariff law of Au
# removing former and preventing new,
# undue discrimi nation s against American commerce it is believed that th
# carrying American goods. All the great commercial
#  nation s pay heavy subsidies to their merchant marine so
# rosperity are as broad as the land. In the dissemi nation  of useful
# information and in the coordination of
# semination of useful
# information and in the coordi nation  of effort certain unofficial
# associations have do
# ch official
# standing as that, for example, of the  Nation al Red Cross.
#
# With these factors and the continua
# tandards which the successful conduct of our inter nation al
# relations and commerce requires.
#
# I therefore a
# or the perpetuation of the present system of exami nation s and
# promotions upon merit and efficiency would b
# d be of greatest value to our
# commercial and inter nation al interests.
#
# PART III.
#
# THE WHITE HOUSE, Decembe
# cipal source of our imported wool.
#
# These discrimi nation s could be overcome by assessing a duty in ad valo
# f evil of the present system, namely, the discrimi nation
# due to different shrinkages, and thereby tends gr
# e debt bearing no interest, including greenbacks,
#  nation al bank notes to be redeemed, and fractional curre
#  kept
# steadily up. Provision is made for the elimi nation  of 134 positions during
# the coming year. Two hund
# nd 141 positions in the year 1910, making an elimi nation  Of
# 542 statutory positions since March 4, 1909; a
# the discharge of anybody, because the normal resig nation s and deaths have
# been equal to the elimination of
# signations and deaths have
# been equal to the elimi nation  of the places, a system of transfers having
# taken
# ing and currency problems so long confronting the  Nation  and to furnish
# the facts and data necessary to en
#  report of the commission promises to
# represent a  nation al movement, the details of the report are still b
# iminated. And ingenious and novel as the proposed  Nation al
# Reserve Association appears, it simply is a log
# ting of perfect equality of opportunity. Both the
#  Nation al system and the State system should be fairly re
# onsolidation of the money or banking power of the  Nation  shall be
# defeated.
#
# It will always be possible, o
# sideration it has received from the people of the
#  Nation  has been wholly nonpartisan; and the Congress set
# ces and a certainty that there will be no discrimi nation
# between those who wish to avail themselves of suc
# mission of tolls, can
# not be held to be a discrimi nation  in the use of the canal. The practice in
# the Suez
#  the Mississippi to the Gulf of Mexico, is
# one of  nation al importance. In view of the work already accompl
# etch of this waterway and made
# it an asset of the  Nation , and in view of the fact that the people of
# Illin
# on lines which while providing a
# waterway for the  Nation  should otherwise benefit that State to the fulles
# General shows that he has subjected to close
# exami nation  the accounts of the clerks of the Federal courts;
# ed, unless it appears to the court,
# after an exami nation  of the entire cause, that the error complained of
# department have been designated. Withholding
# desig nation  from postmasters with unsatisfactory ratings has
# far number approximately 150,000. They include 40
#  nation alities, native Americans largely predominating an
# en pounds, which
# is the weight limit for the inter nation al parcel post, or at the post
# office from which s
# so great and so important
# to the interests of the  Nation  that I shall present it to Congress as a
# separate
# proposed to amalgamate
# with the line.
#
# COUNCIL OF  NATION AL DEFENSE.
#
# I urge again upon Congress the desira
# s the desirability of establishing the council of
#  nation al defense. The bill to establish this council was
# the council is to determine the general
# policy of  nation al defense and to recommend to Congress and to the
# nized with a view of the
# necessities of the whole  Nation  rather than of separate departments.
#
# DEPARTMENTS
# iciency of the Government
# as such a system.
#
# ELIMI NATION  OF ALL LOCAL OFFICES FROM POLITICS.
#
# I wish to re
# e more violent purposes,
# the public councils of a  nation  more able to maintain than it was to
# require its
#  be provided to meet them.
#
# From this view of the  nation al affairs Congress will be urged to take up
# witho
# ly blow at our growing prosperity, perhaps at our  nation al
# existence. He has avowed his purpose of trampli
# ead of dismay, will kindle in every bosom an
# indig nation  not to be extinguished but in the disaster and ex
# l invaders.
#
# In providing the means necessary the  Nation al Legislature will not distrust
# the heroic and en
# n of every kind which the safety and
# honor of the  nation  demand. We have seen them everywhere paying their
# iberate for the
# public good. The gratitude of the  nation  to the Sovereign Arbiter of All
# Human Events shou
# e and to
# depress prices throughout all commercial  nation s, but notwithstanding these
# causes, the United St
# h inheritance from
# our fathers. While enlightened  nation s of Europe are convulsed and
# distracted by civil
# ct of just
# pride that our fame and character as a  nation  continue rapidly to advance
# in the estimation of
# titutions it is to be attributed that while other
#  nation s have achieved glory at the price of the sufferin
# m happy to inform you that our relations with all  nation s are friendly
# and pacific. Advantageous treaties
# cial policy has been adopted by other
# enlightened  nation s, and our trade has been greatly enlarged and ext
# noninterference in the domestic concerns of other
#  nation s. We recognize in all nations the right which we
# ic concerns of other
# nations. We recognize in all  nation s the right which we enjoy ourselves, to
# change an
#  but from a sacred regard for the
# independence of  nation s. While this is our settled policy, it does not
# f
# d desire to cultivate peace and commerce with
# all  nation s. Tranquility at home and peaceful relations abro
# manent policy of our country. War, the scourge of  nation s,
# sometimes becomes inevitable, but is always to
#
# done consistently with the rights and honor of a  nation .
#
# One of the most important results of the war in
#  which we were recently
# forced with a neighboring  nation  is the demonstration it has afforded of
# the milit
# and erroneous views
# of our physical strength as a  nation  and of our ability to prosecute war,
# and especial
# they had not conceived that it was possible for a  nation
# without such an army, well disciplined and of lon
# ency which is
# likely to arise in the affairs of a  nation .
#
# The war with Mexico has developed most striking
# ions on land. The Navy is an important arm of the
#  nation al defense. If the services of the Navy were not s
# rruptedly our cherished policy of "peace
# with all  nation s, entangling alliances with none."
#
# Occupying, as
# pying, as we do, a more commanding position among  nation s than at any
# former period, our duties and our re
# t to the War Department of the result of his exami nation  and the facts
# obtained on the spot is herewith la
#  own ports, to be recoined or used to sustain her
#  nation al bank, and thus contribute to increase her abili
# d will add more to
# the strength and wealth of the  nation  than any which have preceded them
# since the adopt
# the opening prospects of increased
# prosperity and  nation al greatness which the acquisition of these rich a
#  amazement upon the folly of such a course. Other  nation s at the
# present day would look upon it with aston
# n, its harmony, and
# our continued prosperity as a  nation , to adjust at its present session
# this, the only
# y be
# expected from a scientific and skillful exami nation  of the whole face of
# the coast will be eminently
# ropriety of making appropriations for these great  nation al objects.
# Proper defenses on land will be necess
# n be made for a geological and mineralogical
# exami nation  of these regions. Measures should be adopted to p
# merce and navigation and such
# the addition to the  nation al wealth that the present generation may live to
#
# thence in one of our vessels
# of war to their desti nation . The governor was fully advised of the great
# impo
# cessary for the use of the Government by the termi nation  of
# the war, and $20,695,435.30 from loans already
# dit and commerce of so
# many great and enlightened  nation s of Europe.
#
# Severe commercial revulsions abroad
#  extended, and would have added still more to the
#  nation al wealth and public prosperity. But notwithstandi
# ugh our debt, as compared with that of
# most other  nation s, is small, it is our true policy, and in harmony
#  to us a still more commanding position among the  nation s
# of the earth.
#
# The public expenditures should be
# ,
# the detachments have not yet reached their desti nation . Notwithstanding the
# extension of the limits of o
#  not less than seventeen afloat. While
# this great  nation al advantage is secured, our social and commercial
# rom
# assuming and maintaining the first rank among  nation s but a disregard of
# the experience of the past an
# d
# necessary and unavoidable in vindication of the  nation al rights and honor.
# The present condition of the
# and so constituted as to throw the whole power of
#  nation s into the hands of a few, who taxed and controlle
# n that arrangement they conceived the
# strength of  nation s in war consisted. There was also something fasci
# at which they
# admired abroad. Great Britain had a  nation al bank of large capital, in
# whose hands was conce
# e controlling monetary and financial power
# of the  nation --an institution wielding almost kingly power, and
# mmeled the productive industry of the mass of the
#  nation . By her combined system of policy the landlords a
# system in the United States
# was the creation of a  nation al bank. Not foreseeing the dangerous power and
# co
# prosperity, but looked upon its continuance as no  nation al evil.
# Whilst the debt existed it furnished alim
# ilst the debt existed it furnished aliment to the  nation al bank and
# rendered increased taxation necessary
# dangerous
# infraction of the Constitution.
#
# That a  nation al bank, a protective tariff--levied not to raise
# the Constitution.
#
# But it has been urged that the  nation al bank, which constituted so
# essential a branch o
# nally decide against
# the bill for incorporating a  nation al bank, the bill being then before
# him.
#
# Among th
# he whole country has become satisfied that banks,
#  nation al or State, are not necessary as fiscal agents of
# d speedily draw after it the reestablishment of a
#  nation al bank, the revival of a protective tariff, the d
#  the distant future of the
# payment of the present  nation al debt, but its annual increase.
#
# I entertain the
# inst consequences so ruinous is an object of high  nation al
# importance, involving, in my judgment, the cont
# st the effects of hasty action, of error, of
# combi nation , and of possible corruption. Error, selfishness,
#  will deny that in the State governments, by
# combi nation s of individuals and sections, in derogation of th
#  career of glory and happiness to which all other  nation s have been
# strangers.
#
# In the exercise of the pow
#  Congress is
# conclusive evidence that it is an ema nation  of the popular will. A majority
# of the whole numb
# ome and to elevate or
# depress the estimate of our  nation al character abroad.
#
# Invoking the blessings of th
# eral condition of
# our affairs may well excite our  nation al pride.
#
# I can not avoid congratulating you, and
# duce to the common good.
#
# The experience of other  nation s admonished us to hasten the
# extinguishment of th
# itutions to lock up in
# vaults the treasure of the  nation . To take from the people the right of
# bearing arm
# ibuting it may be forcibly illustrated by an exami nation  of the
# effects already produced by the present de
# shown by the annexed table, marked A.
#
# By an exami nation  of that table it will be perceived that in the
# di
# ng power, and I feel persuaded that a mature
# exami nation  of the subject will satisfy everyone that there a
# f a considerable surplus after the payment of the
#  nation al debt. In view of the dangers of such a surplus,
# e as
# intended to authorize the establishment of a  nation al bank, which was
# to issue a currency of bank not
# eated the institution.
#
# On the establishment of a  nation al bank it became the interest of its
# creditors th
# t of the United States.
#
# Such was the origin of a  nation al bank currency, and such the beginning
# of those
# from circulation bank notes of still higher denomi nation s,
# and the object may be materially promoted by fu
# uch banks as continue to
# issue notes of low denomi nation s and throw impediments in the way of
# the circulat
# e known
# at the seat of Government before the termi nation  of your last session
# you are already acquainted,
# ted much surprise and disappointment. A full expla nation
# has been required of the causes which led to the
# he requisite appropriations in
# resuming the great  nation al work of completing the unfinished
# fortification
# e Army as entitled to your favorable regard.
#
# The  nation al policy, founded alike in interest and in humani
#  the people of the United States and the
# European  nation s, and particularly with the British Islands, has
# nlarged intercourse among the people of different  nation s, which can
# not but have a happy effect. Through
# em in the years that are ahead of us.
#
# But if the  Nation 's problems are continuing, so are this great Nati
# tion's problems are continuing, so are this great  Nation 's
# assets:
#
# --our economy,
#
# --the democratic syste
# t important that we all realize tonight that this  Nation
# is close to full employment--with less unemployme
# gh on
# our commitments would be a tragedy for this  Nation .
#
# This much is certain: No one man or group of me
# cts as one.
#
# They express America's common determi nation  to achieve goals. They imply
# action.
#
# In most cas
# y the minimum of $55 should get $80
# a month.
#
# Our  Nation , too, is rightfully proud of our medical advances
# ld
# remember that our country ranks 15th among the  nation s of the world in its
# infant mortality rate.
#
# I th
# paradox of poverty in the midst of
# plenty in this  nation ."
#
# This is the richest nation in the world. The a
# t of
# plenty in this nation."
#
# This is the richest  nation  in the world. The antipoverty program has had
# man
# here they can work to earn their own
# living.
#
# The  Nation 's commitment in the field of civil rights began w
# partments. The prohibition against racial
# discrimi nation  in that act should be remembered and it should be
# k chiefly by the local governments throughout the  Nation --if we
# expect to reduce the toll of crime that we
# hest in our history, and record wages.
#
# Our gross  nation al product has grown more in the last 5 years than
#  in the last 5 years than any
# other period in our  Nation 's history. Our wages have been the highest. Our
# p
# only among the superpowers, but among the smaller  nation s as
# well. We have joined in the test ban treaty o
# rked on a program of trying to
# aid the developing  nation s. We knew then that we could not live in good
# con
# e policies that have helped us become
# the leading  nation  in world trade,
#
# --that we strengthen the interna
# on in world trade,
#
# --that we strengthen the inter nation al monetary system as an instrument of
# world prosp
# with the Soviet Union where the interests
# of both  nation s and the interests of world peace are properly se
# s regular forces more than 4 years
# ago.
#
# The free  nation s of Asia know what they were not sure of at that
#  been honored to be their Commander in Chief. The  Nation  owes them its
# unstinting support while the battle
# nt, as I saw it, on some of the issues before our  Nation , as I view
# them, before I leave.
#
# The other was j
#  world.
#
# In meeting some of these challenges, the  Nation  has found a new confidence.
# In meeting others, it
# I believe deeply in the ultimate purposes of this  Nation --described by the
# Constitution, tempered by histo
# tantial progress has been made during the year in  nation al peace and
# security; the fundamental strength of
# ace and
# security; the fundamental strength of the  Nation 's economic life is
# unimpaired; education and scie
# ng the past 12 months we have suffered with other  Nation s from economic
# depression.
#
# The origins of this d
# ld by creating unemployment in all
# the industrial  nation s. The political agitation in Asia; revolutions in
# t sturdiness and independence which built a great  Nation .
#
# Our people are responding to these impulses in
# ary
# cooperation in the community. The Government,  Nation al, State, and local,
# can join with the community
# rwise have been the case. Of equal importance the  Nation  has had
# unusual peace in industry and freedom fro
# ion of cooperation has been that our governments,
#  Nation al, State, and local, the industries and business
# ople would be more largely
# depleted. We have as a  Nation  a definite duty to see that no deserving
# person i
#  and as a result of its conclusions I appointed a  nation al
# committee comprising the heads of the important
#
# therefore necessary to avoid increase in taxes.
#
#  NATION AL DEFENSE
#
# Our Army and Navy are being maintained
#  the States.
#
# RAILWAYS
#
# We have determined upon a  nation al policy of consolidation of the railways
# as a ne
#  Government of its own facilities.
#
# VETERANS
#
# The  Nation  has generously expanded its care for veterans. Th
# eir property, and that they
# recognized their inter nation al obligations.
#
# A commission which was supported
#  nor regret for the causes which produce it;
# as a  nation  we are reminded that whatever interrupts the peac
#  maintain peace and friendly intercourse with
# all  nation s.
#
# The wise theory of this Government, so early a
# n many respects to established
# principles of inter nation al law. That law the United States have in their
# f
# islate for all others.
#
# Leaving the transatlantic  nation s to adjust their political system in the
# way they
# ntimate political
# connection with distant foreign  nation s does not conflict with giving the
# widest range t
# or
# threatening to the safety and welfare of other  nation s. Our military
# establishment in time of peace is
# ercise of sovereign rights belonging alike to all  nation s, and
# by many liberally exercised. Under such cir
# f Europe are engaged in
# war the rights of neutral  nation s are endangered. This consideration led,
# in the p
#  doctrine which from the very commencement
# of our  nation al being has been a cherished idea of the statesme
# versally received and respected as a rule of
# inter nation al law. But the refusal of one power prevented thi
# r the present; not, however,
# as a recognized inter nation al fight, but as a mere concession for the time
# be
# peration, however, of these two powerful maritime  nation s in
# the interest of neutral rights appeared to me
# make the doctrine in question a principle of inter nation al law, by means
# of special conventions between th
# hemselves, but also as
# between them and all other  nation s which shall enter into like
# stipulations. None o
# cle, for most obvious
# reasons, is much desired by  nation s having naval establishments large in
# proportion
# r foreign commerce. If it were adopted as an
# inter nation al rule, the commerce of a nation having comparati
# opted as an
# international rule, the commerce of a  nation  having comparatively a small
# naval force would be
# vate property should not be
# seized or molested by  nation al ships of war. Should the leading powers of
# Euro
# s of
# Europe concur in proposing as a rule of inter nation al law to exempt private
# property upon the ocean f
# es. The kindly sentiments
# cherished alike by both  nation s have led to extensive social and commercial
# inte
# any disrespect to France or its
# consul, such expla nation  has been made as, I hope, will be satisfactory.
# S
# the minister of the United States, and after expla nation s to
# this effect he has resumed his journey and ac
# oned, not by the
# general principles of the law of  nation s, but only by special conventions
# which most of t
#  special conventions
# which most of the commercial  nation s have entered into with Denmark. The
# fifth articl
# ound higher duties than those of the most favored
#  nation s. This may be regarded as an implied agreement to
# bly and
# skillfully conducted to a successful termi nation  by the officer to whom it
# was intrusted. A treaty
# gations not
# only toward Mexico, but other foreign  nation s, I have exerted all the
# powers with which I am i
# d it possible to bring the negotiations to a
# termi nation .
#
# As incidental to these questions, I deem it pro
# t deny any of these
# charges; they offered no expla nation , nothing in extenuation of their
# conduct, but con
# or
# indemnification and submissive acquiescence in  nation al indignity. It would
# have encouraged in these la
#  nucleus around which the volunteer forces of the  nation
# can promptly gather in the hour of danger, suffic
# approve of the proposed apprentice system for our
#  nation al vessels recommended by the Secretary of the Nav
# the same principle be
# applied to acts of insubordi nation , cowardice, or other misconduct on the
# part of ma
# 0,000,000. The dangers likely to result
# from combi nation s of interests of this character can hardly be
# ove
#  subject will not fail to elicit a careful
# reexami nation  and rigid scrutiny. It was my intention to presen
# newed. Many of these objects partake largely of a  nation al character, and
# are important independently of t
# r execution, and to frown indignantly
# on all combi nation s to resist them; to harmonize a sincere and arden
# y; to
# cultivate peace and friendship with foreign  nation s, and to demand and
# exact equal justice from all,
# o wrong to none; to eschew
# intermeddling with the  nation al policy and the domestic repose of other
# governm
# ty, and elevate and liberalize the intercourse of  nation s; and by
# such just and honorable means, and such
# ll causes of serious misunderstanding
# between two  nation s associated by so many ties of interest and kindr
# ally null so far as regards our rights, this inter nation al
# difficulty can not long remain undetermined wit
# in this relation as the laws of
# war, the usage of  nation s, or special treaties may impose; and it is our
# s
# e undeniable rights of neutrality, individual and  nation al,
# the United States will under no circumstances
# rds of war, his
# acts do not involve any breach of  nation al neutrality nor of themselves
# implicate the Gove
# present war in
# Europe, our citizens have, without  nation al responsibility therefor, sold
# gunpowder and arm
# er and arms to all buyers, regardless of the desti nation  of those
# articles. Our merchantmen have been, and
# tile marine is not interdicted either by the inter nation al or by our
# municipal law, and therefore does not
#  our municipal law, in accordance with the law of  nation s,
# peremptorily forbids not only foreigners, but o
# nts are also in strict conformity with the law
# of  nation s, which declares that no state has the right to r
# to do it without
# such consent is an attack on the  nation al sovereignty.
#
# Such being the public rights and
#  entered upon with full
# knowledge of our laws and  nation al policy and conducted by responsible
# public func
# olls not
# being justified by any principle of inter nation al law, it became the right
# and duty of the United
# rk to treat one of the great maritime highways of  nation s as a
# close sea, and prevent the navigation of it
# on, not unlike the present, signalized
# its determi nation  to maintain the freedom of the seas and of the gr
# long time
# coerced the payment of tribute from all  nation s whose ships frequented the
# Mediterranean. To the
# fering less by their depredations than many other
#  nation s, returned the explicit answer that we preferred
# us tax, so long submitted to by the more powerful  nation s of
# Europe.
#
# If the manner of payment of the Soun
# ould not be competent to deal with the great
# inter nation al principle involved, which affects the right in
# also acceded to a declaration recognizing as inter nation al rights the
# principles contained in the conventi
# alse returns, and also requiring
# them on the termi nation  of their service to deliver to their successors a
# f the Indians, with indications of extensive combi nation s of a
# hostile character among the tribes in that
#
# or over zeal in social improvement, or mere imagi nation  of grievance,
# having but remote connection with a
# them to the level
# of the richest and the greatest  nation s of Europe. And the admirable
# adaptation of our p
# he
# Northern States with angry and resentful condem nation  and complaint,
# because it did not concede all whi
# s. In that
# crisis intense solicitude pervaded the  nation . But the patriotic impulses
# of the popular heart,
# em in the enjoyment of the common heritage of our
#  nation al institutions.
#
# Nor is it hostility against thei
# he continued world-wide economic disturbance. Our  nation al
# concern has been to meet the emergencies it has
# d these immediate emergencies we find
# fundamental  nation al gains even amid depression. In meeting the prob
# e life of our country and are but transitory. The
#  Nation  has emerged from each of them with increased stre
# ligations of life and work
# which come from them.
#
#  NATION AL DEFENSE
#
# Both our Army and Navy have been maint
# lishment of their relative strength and thus elimi nation
# of competitive building also implies for ourselve
# ded in those
# treaties. However, none of the other  nation s, parties to these agreements,
# is to-day maintain
# ace with the world. We have cooperated with other  nation s to
# preserve peace. The rights of our citizens ab
# ted the necessity of cooperation by us with other  nation s in
# reasonable effort to restore world confidence
# ich it was apparent that without
# assistance these  nation s must collapse. Apprehensions of such collapse ha
# ural and security markets and so threatened other
#  nation s as to impose further dangers upon us. But of hig
# nd that the sense of
# social responsibility in the  Nation  has responded to the need of the
# unfortunate.
#
# To
# sing from the
# reaction to acute crisis abroad the  Nation al Credit Association was set up
# by the banks with
# of financial institutions, yet our self-contained  nation al
# economy, with its matchless strength and resour
# hreaten our position, because the balance of
# inter nation al payments is in our favor; we owe less to foreig
# on of the debt and
# represented an increase of the  nation al debt by $616,000,000. Of this,
# however, $153,00
# etirements this would
# indicate an increase in the  nation al debt for the fiscal year 1933 of about
# $921,000
# . Such a basis will give confidence in
# the determi nation  of the Government to stabilize its finance and wi
#  This plan has been warmly indorsed by the recent  Nation al Conference
# upon Home Ownership and Housing, who
# k spots to thus
# liberate the full strength of the  Nation 's resources. It should be in
# position to facilita
# ent. Its functions would not overlap those
# of the  Nation al Credit Corporation.
#
# FEDERAL RESERVE ELIGIBILIT
# ties in our system of veterans' relief; it is our  nation al duty to
# meet our obligations to those who have
# meet our obligations to those who have served the  Nation . But our present
# expenditure upon these services
#
# eliminate overlap and waste, and to enable coordi nation  and definition of
# Government policies now wholly
# economies, sounder policies, more effective
# coordi nation  to employment, and expedition in all construction
# e have found to be the basis of the growth of the
#  Nation . The Federal Government must not encroach upon no
# easure of responsibility in the
# government of the  Nation  rests upon local self-government, so does the
# lar
# reedom and his own liberty.
# It is the duty of the  Nation al Government to insist that both the local
# govern
# al opportunity
# which it has represented among all  nation s since its beginning.
#
# The White House,
#
# December
# e of our restraint as they have
# in the past. This  Nation  simply cannot accept anything less without
# jeopar
#  in
# all the history of trade negotiations.
#
# --The  nation s of Latin America at Punta del Este resolved to m
# move toward
# economic integration.
#
# --In Asia, the  nation s from Korea and Japan to Indonesia and Singapore
#
# ...
# the United States and the condem nation  of private property for the uses
# of the canal, th
#  our success has
# been our ability, foremost among  nation s, to preserve our lasting values by
# making change
# able plan. They proved
# that, when it comes to the  nation al welfare, Americans can still pull
# together for
# e said, "change is the order of the day. In every
#  nation  economic problems long in the making have brought
# ad, ensuring more jobs and better incomes for the  Nation 's work force.
# But our confidence must also be tem
#  could mean as much as a trillion
# dollars more in  nation al debt in the next 4 years alone. That would aver
# debt for every man, woman, child, and baby in our
#  nation .
#
# To assure a sustained recovery, we must continu
# gh, and we will leave an
# unconscionable burden of  nation al debt for our children. That we must not
# do.
#
# Le
# ense spending. Taken as a percentage of the gross
#  nation al product, our defense spending happens to be onl
# n with our tax cuts, taxes as a fraction of gross  nation al
# product remain about the same as they were in 1
# ic
# spending.
#
# During the 1970's, the share of our  nation al income devoted to this
# domestic spending increa
# ansition. It must be
# prudent. The strength of our  nation al defense must be restored so that we
# can pursue
# r America's security. We will not gamble with our
#  nation al survival.
#
# And fourth, because we must ensure r
# ecause we must ensure reduction and eventual elimi nation  of
# deficits over the next several years, I will p
# x, limited
# to no more than 1 percent of the gross  nation al product, to start in fiscal
# 1986. It would last
# l
# propose a broader strategy in the field of inter nation al trade--one that
# increases the openness of our t
# es and make changes in our domestic laws and inter nation al trade
# policy to promote free trade and the incr
# ss. Every American
# has a role and a stake in inter nation al trade.
#
# We Americans are still the technologica
# e, once and for all, all traces of unjust
# discrimi nation  against women from the United States Code. We wil
# ed States Code. We will not
# tolerate wage discrimi nation  based on sex, and we intend to strengthen
# enforce
# its reauthorization. Effective enforcement of our  nation 's
# fair housing laws is also essential to ensuring
# 1st century.
#
# But let us turn briefly to the inter nation al arena. America's leadership in
# the world came t
# democracies of Europe and
# Japan and with the Inter nation al Monetary Fund to ensure it has adequate
# resourc
# be an unrelenting advocate of
# free trade. As some  nation s are tempted to turn to protectionism, our
# strate
# spect the rights
# and sovereignty of the family of  nation s. Responsible members of the world
# community do n
# verwhelming evidence of Soviet violations of inter nation al treaties
# concerning chemical and biological wea
# uclear forces, we have proposed the
# complete elimi nation  of the entire class of land-based missiles. We're
# rselves have gathered within these
# walls when our  nation  was threatened; sometimes when its very existence
# epresentatives. The address was broadcast live on  nation wide radio
# and television.
# over, the
# circumstances of this, the third assassi nation  of an American
# President, have a peculiarly sinis
# virtues which are all-important in the make-up of
#  nation al character. A gallant soldier in the great war f
# alth and irresponsible
# power. But for this assassi nation  even this base apology cannot be
# urged.
#
# Presiden
# e blow not as struck at him, but as struck at the  Nation  We
# mourn a good and great President who is dead;
#  met his death.
#
# When we turn from the man to the  Nation , the harm done is so great as
# to excite our grave
# tically the
# embodiment of the popular will of the  Nation  expressed through the
# forms of law as a New Engla
# rime should be made an offense against
# the law of  nation s, like piracy and that form of man-stealing known
# rs business confidence has been restored, and
# the  nation  is to be congratulated because of its present abo
# fare of the aggregate of citizens which
# makes the  nation , must rest upon individual thrift and energy,
# res
# ling with corporations is to be
# found in the inter nation al commercial conditions of to-day. The same
# busin
# wealth have made them very potent factors in
# inter nation al Commercial competition. Business concerns which
#  in the strife for commercial
# supremacy among the  nation s of the world. America has only just begun
# to ass
# un
# to assume that commanding position in the inter nation al business world
# which we believe will more and m
# o cramp or to fetter the youthful strength of our  Nation .
#
# Moreover, it cannot too often be pointed out th
# the interests of all. The fundamental rule in our  nation al
# life--the rule which underlies all others--is t
# ir vocation to denounce the great
# industrial combi nation s which are popularly, although with technical
# ina
# , would be
# to incur the risk of such far-reaching  nation al disaster that it would
# be preferable to underta
#  that have placed this country at the head
# of the  nation s struggling for commercial supremacy. It does not
# methods, nor upon
# ignorance of the fact that combi nation  of capital in the effort to
# accomplish great thin
# ne. It is based upon sincere conviction that
# combi nation  and concentration should be, not prohibited, but
# mining how to deal with the great
# industrial combi nation s is knowledge of the facts--publicity. In the
# int
# erefore, in the interest of the whole people, the  Nation  should,
# without interfering with the power of the
#
# probable that supervision of corporations by the  Nation al Government
# need not go so far as is now the cas
# ve that a law can be framed which will enable the  Nation al
# Government to exercise control along the lines
# sis, and making firm our new position in the inter nation al industrial
# world; while scrupulously safeguardi
#  to make its enforcement entirely effective.
#
# The  Nation al Government should demand the highest quality of
# nd only to this comes the power
# of acting in combi nation  or association with others. Very great good
# has b
# f these qualities in such bodies is a
# duty to the  nation  no less than to the associations themselves.
# Fina
# ion by the State and
# the municipality than by the  nation . But on points such as those
# touched on above the
#  But on points such as those
# touched on above the  Nation al Government can act.
#
# When all is said and done,
# ispensable prerequisite to success in the kind of  nation al life for
# which we strive. Each man must work fo
# inspection abroad and a more rigid
# system of exami nation  at our immigration ports, the former being
# especi
# al acquiescence in our present tariff system as a
#  nation al policy. The first requisite to our prosperity i
# m of reciprocal
# benefit and obligation with other  nation s. Such reciprocity is an
# incident and result of t
# ication of our tariff policy to
# meet our shifting  nation al needs must be conditioned upon the cardinal
# fac
#  and for a liberal
# policy in dealing with foreign  nation s. Whatever is merely petty and
# vexatious in the w
# for what we ask. The cordial relations with other  nation s
# which are so desirable will naturally be promote
# n by the Congress. It is discreditable to us as
# a  Nation  that our merchant marine should be utterly insign
# erly insignificant in
# comparison to that of other  nation s which we overtop in other forms of
# business. We
# s to continue to rely upon the ships of competing  nation s for the
# distribution of our goods. It should be
#  the price of similar obligations issued by other  nation s, is a
# flattering tribute to our public credit. T
# ntly
# desirable to maintain.
#
# In many respects the  Nation al Banking Law furnishes sufficient liberty
# for th
# strict economy in expenditures.
# The fact that our  nation al needs forbid us to be niggardly in providing
# wh
# ing, should make us doubly
# careful to husband our  nation al resources, as each of us husbands his
# private r
# es through
# which the commercial lifeblood of this  Nation  flows. Nothing could be
# more foolish than the ena
# ed by them in the creation and
# maintenance of the  nation al wealth is now more fully realized than ever
# bef
#  our well being.
#
# The practical usefulness of the  nation al forest reserves to the mining,
# grazing, irrigat
# tates would often be inadequate. It is
# properly a  nation al function, at least in some of its features. It
# t in some of its features. It is
# as right for the  Nation al Government to make the streams and rivers of
# th
# se. These irrigation works should be
# built by the  Nation al Government. The lands reclaimed by them should
# ose laws or with vested
# fights. The policy of the  Nation al Government should be to aid
# irrigation in the s
# ing is but
# another name for the upbuilding of the  nation .
#
# The necessary foundation has already been laid
# s expenditure of the public moneys.
#
# Whatever the  nation  does for the extension of irrigation should
# harmo
# d the unaided development of the past
# justify the  nation 's aid and co-operation in the more difficult and
#
# ople
# most concerned. The larger development which  nation al aid insures
# should, however, awaken in every ar
# d, however, awaken in every arid State the determi nation  to make
# its irrigation system equal in justice an
# lems. A careful study should be made, both by the  Nation  and
# the States, of the irrigation laws and condit
#
# Ultimately it will probably be necessary for the  Nation  to co-operate
# with the several arid States in pro
# ver, there are
# weighty reasons of morality and of  nation al interest why the policy
# should be held to have
# d what we
# desired: that she should stand, in inter nation al matters, in closer and
# more friendly relations
# ur administration of the
# islands honorable to our  Nation  by making it of the highest benefit to
# the Filipi
# fore in their history.
#
# It is no light task for a  nation  to achieve the temperamental qualities
# without wh
# f-government after the fashion of the really free  nation s.
#
# History may safely be challenged to show a sin
# ng North and South America. Its
# importance to the  Nation  is by no means limited merely to its material
# eff
# it is one of those great
# works which only a great  nation  can undertake with prospects of
# success, and whic
# ch when done are not only permanent assets in the
#  nation 's material interests, but standing monuments to i
# n canal at any time, and
# which guarantees to this  Nation  every right that it has ever asked in
# connection
# e canal and shall regulate its neutral use by all  nation s on terms of
# equality without the guaranty or int
# thout the guaranty or interference of any outside  nation
# from any quarter. The signed treaty will at once
#  people should be self-respecting
# peace; and this  Nation  most earnestly desires sincere and cordial
# friend
# eing merely a most regrettable but
# necessary inter nation al police duty which must be performed for the
# sak
# cardinal feature of the foreign
# policy of all the  nation s of the two Americas, as it is of the United
# Stat
# soil. It is in no wise intended as hostile to any  nation  in the Old
# World. Still less is it intended to gi
# ike permanence for the lesser among the New World  nation s.
#
# This doctrine has nothing to do with the comme
# erial welfare, and above all to the peace, of our
#  nation  in the future. Whether we desire it or not, we mu
# t, we must henceforth
# recognize that we have inter nation al duties no less than international
# rights. Even
# at we have international duties no less than inter nation al
# rights. Even if our flag were hauled down in th
# ely and for all time to abandon the idea that our  nation  is
# among those whose sons go down to the sea in s
# ry lightest premium for insuring peace which this
#  nation  can possibly pay.
#
# Probably no other great nation
# nation can possibly pay.
#
# Probably no other great  nation  in the world is so anxious for peace as
# we are. T
# ne anything but a subject of derision to whatever  nation
# chooses to disregard it. We desire the peace whic
# worse than folly; it would be a crime against the
#  Nation .
#
# To send any war ship against a competent enemy
# eneral recognition of our altered conditions as a  Nation  and of the
# true meaning of a great war fleet, whi
#
#
# But in addition we should at once provide for a  Nation al Naval Reserve,
# organized and trained under the
# definitely to accept a secondary position in
# inter nation al affairs, not merely in political, but in commer
#  well said that there is no surer way of courting
#  nation al disaster than to be "opulent, aggressive, and u
# ssion of power to these units when acting in combi nation .
#
# The conditions of modern war are such as to mak
#  act for himself and
# at the same time act in combi nation  with others with whom he is no
# longer in the old-
# should be adopted by which there shall be an elimi nation  grade by grade
# of those who seem unfit to render
#  their comrades in the Navy.
#
# The process of elimi nation  of the least fit should be conducted in a
# manner
# n of regulars,
# and if possible also a division of  nation al guardsmen, once a year.
# These exercises might t
# nd made upon them to sustain the interests of the  Nation  and the
# honor of the flag. The individual America
#  education should be given to the officers of the
#  Nation al Guard and others in civil life who desire intel
# d worthless. The
# organization and armament of the  Nation al Guard of the several States,
# which are treated
# failure. Moreover, they
# not only left us a united  Nation , but they left us also as a heritage
# the memory o
# itage
# the memory of the mighty deeds by which the  Nation  was kept united. We
# are now indeed one Nation, on
# the Nation was kept united. We
# are now indeed one  Nation , one in fact as well as in name; we are
# united in
# n our devotion to the flag which is the symbol of  nation al
# greatness and unity; and the very completeness
#  them by practical
# test. Written competitive exami nation s offer the only available means
# in many cases for
# course, places where the written
# competitive exami nation  cannot be applied, and others where it offers
# by
# ffairs, and the maintenance of
# the dignity of the  nation  abroad, combine to make it essential that our
# con
# wn Indian tribes from this evil. Wherever by inter nation al agreement
# this same end can be attained as rega
# ent in our annals. We earnestly hope that
# foreign  nation s will appreciate the deep interest our country ta
# hey will participate in securing its success. The  Nation al
# Government should be represented by a full and
# s. The terrible tragedy of the President's assassi nation
# interfered materially with its being a financial
# lic.
#
# The advancement of the highest interests of  nation al science and
# learning and the custody of objects
# hing races of great North
# American animals in the  Nation al Zoological Park. The urgent needs of
# the Nation
# National Zoological Park. The urgent needs of
# the  Nation al Museum are recommended to the favorable conside
#  Library of Congress, and so entitled,
# is the one  nation al library of the United States. Already the large
# ngress with
# the purpose of encouraging the dissemi nation  of public information,
# were limited to the legiti
#  whatever happens in China must be of the keenest  nation al
# concern to us.
#
# The general terms of the settle
# aving participated in the outbreak.
# Official exami nation s have been forbidden for a period of five years i
#  trade in central and northern China, and an
# inter nation al conservancy board, in which the Chinese Governm
# nd property, restoring order, and vindicating the
#  nation al interest and honor. It behooves us to continue
# f full and fair
# intercourse between China and the  nation s, on a footing of equal rights
# and advantages to
# ull expression.
# When President McKinley died, our  Nation  in turn received from every
# quarter of the Britis
#  thank the Almighty that we are at peace
# with the  nation s of mankind; and we firmly intend that our policy
#  shall
# be such as to continue unbroken these inter nation al relations of mutual
# respect and good will.

# %% [markdown]
# Textacy includes a lot of great information extraction and analysis features, including built-in [corpus vectorization](https://textacy.readthedocs.io/en/stable/api_reference/vsm_and_tm.html#module-textacy.vsm.vectorizers) and [topic modeling](https://textacy.readthedocs.io/en/stable/api_reference/vsm_and_tm.html#textacy.tm.topic_model.TopicModel) by way of [scikit-learn](https://scikit-learn.org/stable/). It also has [text pre-processing](https://textacy.readthedocs.io/en/stable/api_reference/text_processing.html) utilities with sensible defaults.
#
# In [information extraction](https://textacy.readthedocs.io/en/stable/api_reference/information_extraction.html) there are great tools to extract common structures, such as subject-verb-object triples and direct quotations.
#
# While the current version of textacy doesn't support spaCy v3, the main developer, Burton DeWilde, is actively working on updating textacy for compatibility.

# %% [markdown]
# ## Resources for spaCy
#
# - [spaCy 101](https://spacy.io/usage/spacy-101) - spaCy's own intro documentation
# - [Advanced NLP with spaCy](https://course.spacy.io/) - spaCy's own interactive learning course; you don't need to be "ready" for "advanced" work to benefit from going through this course
# - [textacy](https://github.com/chartbeat-labs/textacy) - a Python library built on top of spaCy and scikit-learn to faciliate working with a corpus and providing extra functionality
# - [spaCy universe](https://spacy.io/universe) - extensive collection of packages built on top of or with spaCy for various NLP and text analysis tasks
# - [spaCy youtube videos](https://www.youtube.com/c/ExplosionAI/videos) - Explosion has a lot of great videos on Youtube, and there are a number of other folks who have created great walkthroughs of using different parts of spaCy.
